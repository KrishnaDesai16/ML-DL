# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb

# %%
from numpy.random import randn,randint

# %%
df=pd.DataFrame(randn(1000),index=pd.date_range(start='1/1/2018',periods=1000),columns=['Values'])
tf=pd.DataFrame(randn(1000),index=pd.date_range(start='1/1/2018',periods=1000))

# %%
df.head()
# Out:
#               Values
# 2018-01-01 -0.734407
# 2018-01-02 -0.190472
# 2018-01-03  0.383589
# 2018-01-04  1.712499
# 2018-01-05  0.604839

# %%
tf.plot()

# %%
tf=tf.cumsum()
tf.plot()

# %%
plt.plot(tf)

# %%
df.plot()

# %%
plt.plot(df.cumsum())

# %%
df=pd.read_csv('iris (1).csv')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  target
# 0           5.1          3.5           1.4          0.2       0
# 1           4.9          3.0           1.4          0.2       0
# 2           4.7          3.2           1.3          0.2       0
# 3           4.6          3.1           1.5          0.2       0
# 4           5.0          3.6           1.4          0.2       0

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  target
# 0             5.1          3.5           1.4          0.2       0
# 1             4.9          3.0           1.4          0.2       0
# 2             4.7          3.2           1.3          0.2       0
# 3             4.6          3.1           1.5          0.2       0
# 4             5.0          3.6           1.4          0.2       0
# ..            ...          ...           ...          ...     ...
# 145           6.7          3.0           5.2          2.3       2
# 146           6.3          2.5           5.0          1.9       2
# 147           6.5          3.0           5.2          2.0       2
# 148           6.2          3.4           5.4          2.3       2
# 149           5.9          3.0           5.1          1.8       2
#
# [150 rows x 5 columns]

# %%
ax=df.plot(figsize=(10,8))
ax.set_xlabel('x-axis')
ax.set_ylabel('y-axis')
# Out:
# Text(0, 0.5, 'y-axis')

# %%
df.plot(kind='bar')

# %%
df.drop('target',axis=1,inplace=True)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.iloc[0].plot(kind='bar')

# %%
data=pd.DataFrame(randn(10,4),columns=['a','b','c','d'])
data
# Out:
#           a         b         c         d
# 0  0.221525 -2.116340  1.622810 -2.891026
# 1 -0.999788  0.964437  1.999059 -0.044633
# 2 -2.284872  0.249907  0.655570 -2.656832
# 3 -1.227768  1.034451  1.120812  0.263711
# 4  0.815670  1.231063  0.953720  1.069795
# 5  1.561529 -0.497671  1.128983  0.378814
# 6  1.241497  0.951405 -1.271942 -0.896980
# 7 -0.687986  2.117278  0.754206 -1.346108
# 8 -1.236036 -0.193282  0.410293 -1.551521
# 9  1.929016 -0.206019  0.113854  0.696029

# %%
data.plot(kind='bar')

# %%
data.plot.hist()

# %%
df.plot.hist()

# %%
df.plot(kind='hist',bins=50,stacked=False)

# %%
df.plot(kind='hist',bins=100,stacked=True,orientation='horizontal')

# %%
df['sepal_length'].diff().plot(kind='hist',stacked=True,bins=50)

# %%
data=pd.read_csv('https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv', sep='\t')
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data['Fare'].plot()

# %%
data['Survived'].hist(bins=20)

# %%
df.diff().hist(color='r',alpha=0.1,figsize=(10,6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001F014DA0F88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F014F49E48>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001F014DFE788>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F014E39188>]],
#       dtype=object)

# %%
df.plot.scatter(x='sepal_length',y='sepal_width',c='petal_length')

# %%
df.plot.hexbin(x='sepal_length',y='petal_length',gridsize=4)

# %%
d=df.iloc[0]
d
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# target          0.0
# Name: 0, dtype: float64

# %%
d.plot.pie(figsize=(10,8),fontsize=20)

# %%
d=df.head(3).T
d
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2
# target        0.0  0.0  0.0

# %%
d.plot.pie(subplots=True,figsize=(15,15),autopct='%.2f')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001F01A096A88>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001F01A1E9C88>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001F01A0A6208>],
#       dtype=object)

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df,figsize=(10,10),diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001F01AD184C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F01ABBA808>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F01AD5DA48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F01AD96488>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F01ADCCE48>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001F01AE059C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F01AE3EA08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F01AE77B48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F01AEE2748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F01AF1A908>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001F01AF80E88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F01AFB7F08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F01AFF6048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F01B02F188>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F01B068288>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001F01B09F388>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F01B0D7448>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F01B110548>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F01B14DE48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F01B181788>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001F01B1BA888>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F01B1F3948>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F01B22BA88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F01B264BC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F01B29ECC8>]],
#       dtype=object)

# %%
df['sepal_length'].plot.kde()

# %%
df.plot.kde(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001F01B644808>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001F01B666388>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001F01B6471C8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001F01B88BA88>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001F01B8C4208>],
#       dtype=object)
