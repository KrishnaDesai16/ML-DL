# %%
import pandas as pd

# %%
data=pd.read_csv('ex1.csv',names=['1','2'])
data.head()
# Out:
#           1        2
# a b  c    d  message
# 1 2  3    4    hello
# 5 6  7    8    world
# 9 10 11  12      foo

# %%
data=pd.read_csv('test.tsv',sep='\t')
data.head()
# Out:
#         test   test test.1 test.2 test.3
# sudh    sudh   sudh   sudh   sudh   sudh
# kumar  kumar  kumar  kumar  kumar  kumar

# %%
data=pd.read_csv('ex5.csv',header=None)
data.head()
# Out:
#            0  1   2    3   4        5
# 0  something  a   b    c   d  message
# 1        one  1   2    3   4      NaN
# 2        two  5   6  NaN   8    world
# 3      three  9  10   11  12      foo

# %%
data=pd.read_csv('ex2.csv')
data.head()
# Out:
#    1   2   3   4  hello
# 0  5   6   7   8  world
# 1  9  10  11  12    foo

# %%
data=pd.read_csv('csv_mindex.csv',index_col=['key1','key2'])
data.head()
# Out:
#            value1  value2
# key1 key2
# one  a          1       2
#      b          3       4
#      c          5       6
#      d          7       8
# two  a          9      10

# %%
data=pd.read_csv('ex4.csv',skiprows=[0,2,3])
data.head()
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
url = "http://www.basketball-reference.com/leagues/NBA_2015_totals.html"
data=pd.read_html(url)
df=data[0]
df
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
df.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
data=pd.read_csv('https://raw.githubusercontent.com/akhil12028/Bank-Marketing-data-set-analysis/master/bank-additional-full.csv',sep=';')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data=pd.read_csv(r'https://raw.githubusercontent.com/akhil12028/Bank-Marketing-data-set-analysis/master/bank-additional-full.csv',sep=';')

# %%
data.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
data.tail()
# Out:
#        age          job  marital            education default housing loan  \
# 41183   73      retired  married  professional.course      no     yes   no
# 41184   46  blue-collar  married  professional.course      no      no   no
# 41185   56      retired  married    university.degree      no     yes   no
# 41186   44   technician  married  professional.course      no      no   no
# 41187   74      retired  married  professional.course      no     yes   no
#
#         contact month day_of_week  ...  campaign  pdays  previous  \
# 41183  cellular   nov         fri  ...         1    999         0
# 41184  cellular   nov         fri  ...         1    999         0
# 41185  cellular   nov         fri  ...         2    999         0
# 41186  cellular   nov         fri  ...         1    999         0
# 41187  cellular   nov         fri  ...         3    999         1
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# ...

# %%
data=pd.read_csv(r'https://raw.githubusercontent.com/akhil12028/Bank-Marketing-data-set-analysis/master/bank-additional-full.csv',sep=';',skiprows=[0,2,5])

# %%
data.head()
# Out:
#    56    housemaid  married             basic.4y       no no.1 no.2  \
# 0  37     services  married          high.school       no  yes   no
# 1  40       admin.  married             basic.6y       no   no   no
# 2  45     services  married             basic.9y  unknown   no   no
# 3  59       admin.  married  professional.course       no   no   no
# 4  41  blue-collar  married              unknown  unknown   no   no
#
#    telephone  may  mon  ...  1  999  0  nonexistent  1.1  93.994  -36.4  \
# 0  telephone  may  mon  ...  1  999  0  nonexistent  1.1  93.994  -36.4
# 1  telephone  may  mon  ...  1  999  0  nonexistent  1.1  93.994  -36.4
# 2  telephone  may  mon  ...  1  999  0  nonexistent  1.1  93.994  -36.4
# 3  telephone  may  mon  ...  1  999  0  nonexistent  1.1  93.994  -36.4
# 4  telephone  may  mon  ...  1  999  0  nonexistent  1.1  93.994  -36.4
#
#    4.857    5191  no.3
# 0  4.857  5191.0    no
# 1  4.857  5191.0    no
# 2  4.857  5191.0    no
# 3  4.857  5191.0    no
# ...

# %%
data.columns
# Out:
# Index(['56', 'housemaid', 'married', 'basic.4y', 'no', 'no.1', 'no.2',
#        'telephone', 'may', 'mon', '261', '1', '999', '0', 'nonexistent', '1.1',
#        '93.994', '-36.4', '4.857', '5191', 'no.3'],
#       dtype='object')

# %%
data=data.rename(columns={'age':'Age'})
data
# Out:
#        56    housemaid  married             basic.4y       no no.1 no.2  \
# 0      37     services  married          high.school       no  yes   no
# 1      40       admin.  married             basic.6y       no   no   no
# 2      45     services  married             basic.9y  unknown   no   no
# 3      59       admin.  married  professional.course       no   no   no
# 4      41  blue-collar  married              unknown  unknown   no   no
# ...    ..          ...      ...                  ...      ...  ...  ...
# 41180  73      retired  married  professional.course       no  yes   no
# 41181  46  blue-collar  married  professional.course       no   no   no
# 41182  56      retired  married    university.degree       no  yes   no
# 41183  44   technician  married  professional.course       no   no   no
# 41184  74      retired  married  professional.course       no  yes   no
#
#        telephone  may  mon  ...  1  999  0  nonexistent  1.1  93.994  -36.4  \
# ...

# %%
data['education']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'education'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-0cfb0275a801> in <module>
# ----> 1 data['education']
#
# ...

# %%
data['education'].dtype

# %%
data.dtypes

# %%
data.isnull().sum()

# %%
df=pd.read_csv('ex6.csv',nrows=10)
df
# Out:
#         one       two     three      four key
# 0  0.467976 -0.038649 -0.295344 -1.824726   L
# 1 -0.358893  1.404453  0.704965 -0.200638   B
# 2 -0.501840  0.659254 -0.421691 -0.057688   G
# 3  0.204886  1.074134  1.388361 -0.982404   R
# 4  0.354628 -0.133116  0.283763 -0.837063   Q
# 5  1.817480  0.742273  0.419395 -2.251035   Q
# 6 -0.776764  0.935518 -0.332872 -1.875641   U
# 7 -0.913135  1.530624 -0.572657  0.477252   K
# 8  0.358480 -0.497572 -0.367016  0.507702   S
# 9 -1.740877 -1.160417 -1.637830  2.172201   G

# %%
chunk=pd.read_csv('ex6.csv',chunksize=1000)
chunk

# %%
df=pd.read_csv('out.csv')
# Out:
#    Unnamed: 0 something  a   b     c   d message
# 0           0       one  1   2   3.0   4     NaN
# 1           1       two  5   6   NaN   8   world
# 2           2     three  9  10  11.0  12     foo

# %%
df.to_csv('deamon.csv',sep='@')

# %%
import sys
df.to_csv(sys.stdout,na_rep='NULL')
# Out:
# ,Unnamed: 0,something,a,b,c,d,message
# 0,0,one,1,2,3.0,4,NULL
# 1,1,two,5,6,NULL,8,world
# 2,2,three,9,10,11.0,12,foo

# %%
df.to_csv('demo.csv',header=False,index=False)

# %%
df.to_csv('out6.csv',index=False,columns=['a','b','c'])

# %%
dates=pd.date_range('1/1/2000',periods=7,freq='m')

# %%
import numpy as np
Dates=pd.Series(np.arange(7),index=dates)
Dates
# Out:
# 2000-01-31    0
# 2000-02-29    1
# 2000-03-31    2
# 2000-04-30    3
# 2000-05-31    4
# 2000-06-30    5
# 2000-07-31    6
# Freq: M, dtype: int32

# %%
#---------------------
import csv
f=open('ex7.csv')
reader=csv.reader(f)
reader

# %%
for line in reader:
    print(line)
# Out:
# ['a', 'b', 'c']
# ['1', '2', '3']
# ['1', '2', '3']

# %% [markdown]
# # JSON Data

# %%
obj = """
{"name": "Wes",
 "places_lived": ["United States", "Spain", "Germany"],
 "pet": null,
 "siblings": [{"name": "Scott", "age": 30, "pets": ["Zeus", "Zuko"]},
              {"name": "Katie", "age": 38,
               "pets": ["Sixes", "Stache", "Cisco"]}]
}
"""
type(obj)
# Out:
# str

# %%
import json
result=json.loads(obj)
result
#loads()-->convert str format to dict
# Out:
# {'name': 'Wes',
#  'places_lived': ['United States', 'Spain', 'Germany'],
#  'pet': None,
#  'siblings': [{'name': 'Scott', 'age': 30, 'pets': ['Zeus', 'Zuko']},
#   {'name': 'Katie', 'age': 38, 'pets': ['Sixes', 'Stache', 'Cisco']}]}

# %%
type(result)
# Out:
# dict

# %%
df=pd.DataFrame(result['siblings'])
df
# Out:
#     name  age                    pets
# 0  Scott   30            [Zeus, Zuko]
# 1  Katie   38  [Sixes, Stache, Cisco]

# %%
#example-2

# %%
df=pd.read_json('example.json')
df
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
print(df.to_json())
print(df.to_json(orient='records'))
# Out:
# {"a":{"0":1,"1":4,"2":7},"b":{"0":2,"1":5,"2":8},"c":{"0":3,"1":6,"2":9}}
# [{"a":1,"b":2,"c":3},{"a":4,"b":5,"c":6},{"a":7,"b":8,"c":9}]

# %% [markdown]
# #  Read Html data

# %%
webdata=pd.read_html('fdic_failed_bank_list.html')
type(webdata)
len(webdata)
# Out:
# 1

# %%
failer=webdata[0]
failer.head()
# Out:
#                       Bank Name             City  ST   CERT  \
# 0                   Allied Bank         Mulberry  AR     91
# 1  The Woodbury Banking Company         Woodbury  GA  11297
# 2        First CornerStone Bank  King of Prussia  PA  35312
# 3            Trust Company Bank          Memphis  TN   9956
# 4    North Milwaukee State Bank        Milwaukee  WI  20364
#
#                  Acquiring Institution        Closing Date       Updated Date
# 0                         Today's Bank  September 23, 2016  November 17, 2016
# 1                          United Bank     August 19, 2016  November 17, 2016
# 2  First-Citizens Bank & Trust Company         May 6, 2016  September 6, 2016
# 3           The Bank of Fayette County      April 29, 2016  September 6, 2016
# 4  First-Citizens Bank & Trust Company      March 11, 2016      June 16, 2016

# %% [markdown]
# # Binary Data Fromat

# %%
df=pd.read_csv('ex1.csv')
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
df.to_pickle('frame_pickle')

# %%
data=pd.read_pickle('frame_pickle')

# %%
data
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %% [markdown]
# # Web APIs

# %%
import requests
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'
resp=requests.get(url)

# %%
type(resp)
# Out:
# requests.models.Response

# %%
resp
# Out:
# <Response [200]>

# %%
data=resp.json()

# %%
len(data)
# Out:
# 30

# %%
type(data)
# Out:
# list

# %%
df1=pd.DataFrame(data,columns=['number', 'title',
                                     'labels', 'state','user'])
df1.head()
# Out:
#    number                                              title  \
# 0   35383  Remove similar rows of dataframe if have diffe...
# 1   35382  BUG: Inconsistent ordering of rows when mergin...
# 2   35381                                    Storage options
# 3   35380  CLN: resolve isort mypy import confilict test_...
# 4   35379  DOC: Expanded Using a Docker Container section...
#
#                                               labels state  \
# 0  [{'id': 1954720290, 'node_id': 'MDU6TGFiZWwxOT...  open
# 1  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 2                                                 []  open
# 3                                                 []  open
# 4  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
#
#                                                 user
# 0  {'login': 'paulthemagno', 'id': 38130299, 'nod...
# 1  {'login': 'pandamatic', 'id': 68654702, 'node_...
# 2  {'login': 'martindurant', 'id': 6042212, 'node...
# ...

# %%
a=[]
b=[]
c=[]
e=[]
f=[]
g=[]
h=[]
x=[]
j=[]
k=[]
l=[]
m=[]
n=[]
o=[]
p=[]
q=[]
r=[]



for i in df1.user:
        a.append(i['id'])
for i in df1.user:
        b.append(i['node_id'])
for i in df1.user:
        c.append(i['gravatar_id'])

for i in df1.user:
        e.append(i['type'])

for i in df1.user:
        f.append(i['site_admin'])
        

for i in df1.user:
        g.append(i['avatar_url'])
for i in df1.user:
        h.append(i['url'])
for i in df1.user:
        x.append(i['html_url'])

for i in df1.user:
        j.append(i['followers_url'])

for i in df1.user:
        k.append(i['following_url'])

for i in df1.user:
        l.append(i['gists_url'])
for i in df1.user:
        m.append(i['starred_url'])
for i in df1.user:
        n.append(i['subscriptions_url'])

for i in df1.user:
        o.append(i['organizations_url'])

for i in df1.user:
        p.append(i['repos_url'])
        
        

for i in df1.user:
        q.append(i['events_url'])

for i in df1.user:
        r.append(i['received_events_url'])
        
        

        








df1['user_id']=a

df1['user_node_id']=b

df1['user_grav_id']=c

df1['user_type']=e

df1['user_sit_admin']=f

df1['user_vatar_url']=g

df1['user_url']=h

df1['user_htm_url']=x

df1['user_followers_url']=j

df1['user_following_url']=k

df1['user_gists_url']=l

df1['user_starred_url']=m

df1['user_subscriptions_url']=n

df1['user_organizations_url']=o

df1['user_repos_url']=p

df1['user_events_url']=q
df1['user_received_events_url']=r

df1.drop('user',axis=1,inplace=True)

# %%
df1.head()
# Out:
#    number                                              title  \
# 0   35383  Remove similar rows of dataframe if have diffe...
# 1   35382  BUG: Inconsistent ordering of rows when mergin...
# 2   35381                                    Storage options
# 3   35380  CLN: resolve isort mypy import confilict test_...
# 4   35379  DOC: Expanded Using a Docker Container section...
#
#                                               labels state   user_id  \
# 0  [{'id': 1954720290, 'node_id': 'MDU6TGFiZWwxOT...  open  38130299
# 1  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open  68654702
# 2                                                 []  open   6042212
# 3                                                 []  open   7614606
# 4  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open  24970830
#
#            user_node_id user_grav_id user_type  user_sit_admin  \
# 0  MDQ6VXNlcjM4MTMwMjk5                   User           False
# ...

# %%
d=pd.DataFrame(df1['labels'],columns=['id','node_id'])
# Out:
# Empty DataFrame
# Columns: [id, node_id]
# Index: []

# %%
s=[{'id':3},{'id':6}]
s[0]['id']
# Out:
# 3

# %%
df1
# Out:
#     number                                              title  \
# 0    35383  Remove similar rows of dataframe if have diffe...
# 1    35382  BUG: Inconsistent ordering of rows when mergin...
# 2    35381                                    Storage options
# 3    35380  CLN: resolve isort mypy import confilict test_...
# 4    35379  DOC: Expanded Using a Docker Container section...
# 5    35378                   DOC:  Data Editing Samples/Guide
# 6    35377  [FIX] Handle decimal and thousand separator in...
# 7    35376                          BUG: inconsistant replace
# 8    35375                  ENH: Collation argument to to_sql
# 9    35373  ENH: Add validation checks for non-unique merg...
# 10   35372  BUG: Pandas Read_html can't get values from ta...
# 11   35370  BUG: Categorical data is not correctly plotted...
# 12   35369  BUG: df reassignment following reorder_categor...
# 13   35368  DOC: Fix heading capitalization in doc/source/...
# ...

# %%
'''sub_df=pd.DataFrame(columns=['la_id','la_node_id','la_url','name','color','default','description'])
for i in range(30):

         d=pd.DataFrame(df1['labels'][i],columns=['id','node_id','url','name','color','default','description'])
         sub_df=sub_df.append(d,ignore_index=True)'''

# %%
#full_df=pd.concat([df1,sub_df],axis=1)

# %%
#full_df.shape
# Out:
# (49, 31)

# %%
import numpy as np
x=[]
for  i in range(30):
    if len(df1['labels'][i])==0:
        y={'id':np.nan,
           'node_id':np.nan,
           'url':np.nan,
           'name':np.nan,
           'color':np.nan,
           'default':np.nan,
           'description':np.nan
          }
        x.append(y)
    elif len(df1['labels'][i])!=0:
        for j in range(len(df1['labels'][i])):
            x.append(df1['labels'][i][j])
sub_df=pd.DataFrame(x)


sub_df
# Out:
#               id                   node_id  \
# 0   1.954720e+09  MDU6TGFiZWwxOTU0NzIwMjkw
# 1   3.444454e+07  MDU6TGFiZWwzNDQ0NDUzNg==
# 2   7.681100e+04      MDU6TGFiZWw3NjgxMQ==
# 3   1.954720e+09  MDU6TGFiZWwxOTU0NzIwMjkw
# 4            NaN                       NaN
# 5            NaN                       NaN
# 6   1.346990e+05      MDU6TGFiZWwxMzQ2OTk=
# 7   1.346990e+05      MDU6TGFiZWwxMzQ2OTk=
# 8   1.954720e+09  MDU6TGFiZWwxOTU0NzIwMjkw
# 9   7.681100e+04      MDU6TGFiZWw3NjgxMQ==
# 10  4.722917e+07  MDU6TGFiZWw0NzIyOTE3MQ==
# 11  7.681100e+04      MDU6TGFiZWw3NjgxMQ==
# 12  3.281565e+07  MDU6TGFiZWwzMjgxNTY0Ng==
# 13  1.652721e+09  MDU6TGFiZWwxNjUyNzIxMTgw
# 14  7.681200e+04      MDU6TGFiZWw3NjgxMg==
# 15  1.954720e+09  MDU6TGFiZWwxOTU0NzIwMjkw
# 16  4.267096e+07  MDU6TGFiZWw0MjY3MDk2NQ==
# 17  1.309878e+07  MDU6TGFiZWwxMzA5ODc3OQ==
# 18  7.681100e+04      MDU6TGFiZWw3NjgxMQ==
# 19  1.954720e+09  MDU6TGFiZWwxOTU0NzIwMjkw
# 20  7.681100e+04      MDU6TGFiZWw3NjgxMQ==
# ...

# %%
full_df=pd.concat([df1,sub_df],axis=1)
full_df.drop('labels',inplace=True,axis=1)

# %%
full_df
# Out:
#      number                                              title state  \
# 0   35383.0  Remove similar rows of dataframe if have diffe...  open
# 1   35382.0  BUG: Inconsistent ordering of rows when mergin...  open
# 2   35381.0                                    Storage options  open
# 3   35380.0  CLN: resolve isort mypy import confilict test_...  open
# 4   35379.0  DOC: Expanded Using a Docker Container section...  open
# 5   35378.0                   DOC:  Data Editing Samples/Guide  open
# 6   35377.0  [FIX] Handle decimal and thousand separator in...  open
# 7   35376.0                          BUG: inconsistant replace  open
# 8   35375.0                  ENH: Collation argument to to_sql  open
# 9   35373.0  ENH: Add validation checks for non-unique merg...  open
# 10  35372.0  BUG: Pandas Read_html can't get values from ta...  open
# 11  35370.0  BUG: Categorical data is not correctly plotted...  open
# 12  35369.0  BUG: df reassignment following reorder_categor...  open
# ...
