# %%
import pandas as pd
import numpy as np

# %%
titanic_train = pd.read_csv("https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv",
                           sep='\t')   
titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
categorical_cols=[column for column in titanic_train.columns if titanic_train[column].dtypes=='object' ]
categorical_data=titanic_train[categorical_cols]

# %%
categorical_data.describe()
# Out:
#                                         Name   Sex Ticket Cabin Embarked
# count                                    156   156    156    31      155
# unique                                   156     2    145    28        3
# top     Vestrom, Miss. Hulda Amanda Adolfina  male  11668  C123        S
# freq                                       1   100      2     2      110

# %%
numerical_cols=[column for column in titanic_train.columns if titanic_train[column].dtypes=='int64']
numerical_data=titanic_train[numerical_cols]
numerical_data.describe()
# Out:
#        PassengerId    Survived      Pclass       SibSp       Parch
# count   156.000000  156.000000  156.000000  156.000000  156.000000
# mean     78.500000    0.346154    2.423077    0.615385    0.397436
# std      45.177428    0.477275    0.795459    1.056235    0.870146
# min       1.000000    0.000000    1.000000    0.000000    0.000000
# 25%      39.750000    0.000000    2.000000    0.000000    0.000000
# 50%      78.500000    0.000000    3.000000    0.000000    0.000000
# 75%     117.250000    1.000000    3.000000    1.000000    0.000000
# max     156.000000    1.000000    3.000000    5.000000    5.000000

# %%
c_data=titanic_train['Cabin'].astype(str)
new_data=[cabin[0] for cabin in c_data]
new_data=pd.Categorical(new_data)
new_data
titanic_train['Cabin_1']=new_data

# %%
titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_train['Age'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 151    False
# 152    False
# 153    False
# 154     True
# 155    False
# Name: Age, Length: 156, dtype: bool

# %%
missing=np.where(titanic_train['Age'].isnull()==True)
missing
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154], dtype=int64),)

# %%
max_fare=np.where(titanic_train['Fare']==max(titanic_train['Fare']))
max_fare
# Out:
# (array([27, 88], dtype=int64),)

# %%
new_raws=titanic_train.iloc[np.where(titanic_train['Fare']==max(titanic_train['Fare']))]

# %%
new_raws
# Out:
#     PassengerId  Survived  Pclass                            Name     Sex  \
# 27           28         0       1  Fortune, Mr. Charles Alexander    male
# 88           89         1       1      Fortune, Miss. Mabel Helen  female
#
#      Age  SibSp  Parch Ticket   Fare        Cabin Embarked Cabin_1
# 27  19.0      3      2  19950  263.0  C23 C25 C27        S       C
# 88  23.0      3      2  19950  263.0  C23 C25 C27        S       C

# %%
titanic_train.iloc[max_fare][['Name','Age']]
# Out:
#                               Name   Age
# 27  Fortune, Mr. Charles Alexander  19.0
# 88      Fortune, Miss. Mabel Helen  23.0

# %%
titanic_train.iloc[np.where(titanic_train['Age']==min(titanic_train['Age']))][['Name','Cabin','Age']]
# Out:
#                              Name Cabin   Age
# 78  Caldwell, Master. Alden Gates   NaN  0.83

# %%
titanic_train['family']=titanic_train['SibSp']+titanic_train['Parch']
titanic_train.iloc[np.where(titanic_train['family']==max(titanic_train['family']))]
# Out:
#     PassengerId  Survived  Pclass                                Name     Sex  \
# 59           60         0       3  Goodwin, Master. William Frederick    male
# 71           72         0       3          Goodwin, Miss. Lillian Amy  female
#
#      Age  SibSp  Parch   Ticket  Fare Cabin Embarked Cabin_1  family
# 59  11.0      5      2  CA 2144  46.9   NaN        S       n       7
# 71  16.0      5      2  CA 2144  46.9   NaN        S       n       7

# %%
|#how to convert list into dict and series

# %%
my_data=[10,20,30,40]
labels=['a','b','c','d']
data=pd.Series(my_data,index=labels)
data
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
print('\n Holding data\n','-'*20,sep=' ')
pd.Series([type,min,max])
# Out:
#  Holding data
#  --------------------
# 0             <class 'type'>
# 1    <built-in function min>
# 2    <built-in function max>
# dtype: object

# %%
ser1 = pd.Series([1,2,3,4],index = ['CA','OR','OZ','AB'])
ser2 = pd.Series([1,2,5,4],['CA', 'OR', 'NV', 'AZ'])
ser1+ser2
# Out:
# AB    NaN
# AZ    NaN
# CA    2.0
# NV    NaN
# OR    4.0
# OZ    NaN
# dtype: float64
